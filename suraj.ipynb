# %%
is_student = False
has_id = True
in_dress = True

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom.")

elif is_student and in_dress or has_id:
    print("Check the condition and let them in according to it!")
    if is_student and has_id:
        print("NOt allowed in classroom. But can perform the administrative work")

    elif is_student and in_dress:
        print("Give warning and let them in for the first time")

    else:
        pass

else:
    print("Not allowed.")

# %%
#User authentication

users = {
    "admin": "admin123",
    "suraj": "suraj123"
}

# %%
username = input("Enter username:")
password= input("Enter password:")

# %%
if username in users and users[username] == password:
    print("Login sucessful")
else:
    print("Invalid username or password")

# %%
#Grade calculation
mark = int(input("Enter marks (0-100) :"))

# %%
if mark >= 90:
    grade = "A+"
elif mark >= 80:
    grade = "A"
elif mark >= 70:
    grade = "B+"
elif mark >= 60:
    grade = "B"
elif mark >= 50:
    grade = "C+"
elif mark >= 40:
    grade = "C"
elif mark >= 30:
    grade = "D+"
elif mark >= 20:
    grade = "D"
else :
    grade = "E"

# %%
print("Grade:", grade)

# %%
#Access control

user = {
    "admin": "admin123",
    "suraj": "suraj123",
    "aryan": "aryan123",
    "sameer": "sameer123"
}

# %%
username= input("Enter username:")

# %%
if username in users:
    role = user[username]

    if role == "admin":
        print("Full access granted.")
    else:
        print("Limited access.")
else:
    print("Access denied. ")

# %%
#Data validation

email = input("Enter Email:")

# %%
if "@" in email and "." in email:
    print("valid email")
else:
    print("Invalid email")
