# %% [raw]
# narayan
#
# Logical Operators
# and - Both conditions True
# or  - At least one condition True
# not - Reverse the condition

# %%
is_student = True
has_id = True
in_dress = False

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom.")

elif is_student and in_dress or has_id:
    print("Check the condition and let them in according to it!")
    if is_student and has_id:
        print("NOt allowed in classroom. But can perform the administrative work")

    elif is_student and in_dress:
        print("Give warning and let them in for the first time")

    else:
        pass

else:
    print("Not allowed.")
# Out:
# Check the condition and let them in according to it!
# NOt allowed in classroom. But can perform the administrative work

# %%
is_student = True
has_id = False
in_dress = True

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom.")

elif is_student and in_dress or has_id:
    print("Check the condition and let them in according to it!")
    if is_student and has_id:
        print("NOt allowed in classroom. But can perform the administrative work")

    elif is_student and in_dress:
        print("Give warning and let them in for the first time")

    else:
        pass

else:
    print("Not allowed.")
# Out:
# Check the condition and let them in according to it!
# Give warning and let them in for the first time

# %%
is_student = False
has_id = False
in_dress = True

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom.")

elif is_student and in_dress or has_id:
    print("Check the condition and let them in according to it!")
    if is_student and has_id:
        print("NOt allowed in classroom. But can perform the administrative work")

    elif is_student and in_dress:
        print("Give warning and let them in for the first time")

    else:
        pass

else:
    print("Not allowed.")
# Out:
# Not allowed.

# %%
is_student = False
has_id = False
in_dress = False

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom.")

elif is_student and in_dress or has_id:
    print("Check the condition and let them in according to it!")
    if is_student and has_id:
        print("NOt allowed in classroom. But can perform the administrative work")

    elif is_student and in_dress:
        print("Give warning and let them in for the first time")

    else:
        pass

else:
    print("Not allowed.")
# Out:
# Not allowed.

# %%
is_student = True
has_id = True
in_dress = True

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom.")

elif is_student and in_dress or has_id:
    print("Check the condition and let them in according to it!")
    if is_student and has_id:
        print("NOt allowed in classroom. But can perform the administrative work")

    elif is_student and in_dress:
        print("Give warning and let them in for the first time")

    else:
        pass

else:
    print("Not allowed.")
# Out:
# Entry allowed. Can enter the classroom.

# %% [raw]
# Membership Operators
#
# in     - Value exists in sequence
# not in - Value doesn't exist in sequence

# %%
a= [1,2,3,4,5,8, "hello"]

# %%
if 8 in a:
    print("it is there")
else:
    print("it is not found")
# Out:
# it is there

# %%
if "allo" in a:
    print("itis there")
else:
    print("it is not found")
# Out:
# it is not found

# %% [raw]
# Identity Operators
# is     - Same object in memory
# is not - Different objects in memory

# %%
a = [1, 2, 3]
b = a          
c = [1, 2, 3]  

print(a is b)      
print(a is not b)  

print(a is c)      
print(a is not c)
# Out:
# True
# False
# False
# True

# %% [raw]
# Real-World Applications:
# User authentication
#
# Grade calculation
#
# Discount eligibility
#
# Access control
#
# Data validation

# %% [raw]
# 1. Data validation

# %%
user= "ram"
password= "sdfghjasdfg"

# %%
input_user= input("enter the name:")
input_password= input("enter the password:")
if input_user in user and input_password in password :
    print("user acess granted")
elif input_user not in user and input_password in password :
    print("check username")
elif input_user in user and input_password not in password :
    print("check password")
    
else:
    print("check the crediantials")
# Out:
# enter the name: ram
# enter the password: fasmsd
# check password

# %% [raw]
# Discount eligibility

# %%
price=1000

# %%
if price>500:
    print("you are eligible for 10% discount")
else:
    print("buy more for discount eligibility")
# Out:
# you are eligible for 10% discount

# %% [raw]
# Grade calculation

# %%
math=15
science=20
english=20

# %%
grade=math+science+english
grade
# Out:
# 55

# %%
is_student = False
has_id = True
in_dress = True

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom.")

elif is_student and in_dress or has_id:
    print("Check the condition and let them in according to it!")
    if is_student and has_id:
        print("NOt allowed in classroom. But can perform the administrative work")

    elif is_student and in_dress:
        print("Give warning and let them in for the first time")

    else:
        pass

else:
    print("Not allowed.")
